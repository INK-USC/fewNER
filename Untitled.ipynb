# %%
import random
from tqdm import tqdm
from typing import List, Dict
from sentence_transformers import SentenceTransformer, util
import torch
from torch.utils.data import Dataset
from torch.utils.data._utils.collate import default_collate
from transformers import PreTrainedTokenizer
import collections
import numpy as np
from src.data.data_utils import convert_iobes, build_label_idx, check_all_labels_in_dict
import bert_score
from src.data import Instance

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text)
# output = model(**encoded_input)

# %%
data='dataset/fewnerd/supervised/converted/test.txt'

# %%
with open(data,'r',encoding='utf-8') as f:
    l=f.readlines()

# %%
sents=[]
words=[]
temp=[]
for i in l:
    if i=='\n':
#         print('d')
        sents.append(words)
        words=[]
    else:
        words.append(i.strip().split()[0])

# %%
for i in range(len(sents)):
    sents[i]=' '.join(sents[i])

# %%
sents
# Out:
# ['In the early 1930s the band moved to the Grill Room of the Taft Hotel in New York ; the band was renamed `` George Hall and His Hotel Taft Orchestra `` .',
#  'The final season of minor league play Elkin Memorial Park saw season attendance of 16,322 , an average of 299 per contest .',
#  'They finished the season 14–19 , 9–9 in C-USA play to finish in seventh place .',
#  'The B-52 pilot , Major Larry G. Messinger , later recalled ,',
#  'The Austro-Hungarian Navy built and operated two classes of protected cruisers .',
#  'Elin Hilderbrand is an American writer mostly of romance novels .',
#  "A prototype was fitted in the mid-'60s in a one-off DB5 extended 4 '' after the doors and driven by Marek personally , and a normally 6-cylinder Aston Martin DB7 was equipped with a V8 unit in 1998 .",
# ...

# %%
encoder_input=[]
l=0
for i in sents:
    temp=tokenizer(i)
    l=max(len(temp['input_ids']),l)
    if len(tokenizer.convert_ids_to_tokens(temp['input_ids']))>500:
        print(len((temp['input_ids'])))
        print(tokenizer.convert_ids_to_tokens(temp['input_ids']))
        print(i)
    
#     print((temp['input_ids']))
#     break
#     encoder_input.append(temp)
# Out:
# 504
# ...

# %%
l
# Out:
# 218
